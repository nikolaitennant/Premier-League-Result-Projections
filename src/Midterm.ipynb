# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

fantasy_21_raw = pd.read_csv ('fantasy_21.csv')
fantasy_22_raw = pd.read_csv ('fantasy_22.csv')
matches_21_raw = pd.read_csv ('matches_21.csv')
matches_22_raw = pd.read_csv ('matches_22.csv')
# Out:
#    Div      Date  GW   Time        HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 0   E0    8/5/22   1  20:00  Crystal Palace         Arsenal     0     2   A
# 1   E0    8/6/22   1  12:30          Fulham       Liverpool     2     2   D
# 2   E0    8/6/22   1  15:00     Bournemouth     Aston Villa     2     0   H
# 3   E0    8/6/22   1  15:00           Leeds          Wolves     2     1   H
# 4   E0    8/6/22   1  15:00       Newcastle   Nott'm Forest     2     0   H
# 5   E0    8/6/22   1  15:00       Tottenham     Southampton     4     1   H
# 6   E0    8/6/22   1  17:30         Everton         Chelsea     0     1   A
# 7   E0    8/7/22   1  14:00       Leicester       Brentford     2     2   D
# 8   E0    8/7/22   1  14:00      Man United        Brighton     1     2   A
# 9   E0    8/7/22   1  16:30        West Ham        Man City     0     2   A
# 10  E0   8/13/22   2  12:30     Aston Villa         Everton     2     1   H
# 11  E0   8/13/22   2  15:00         Arsenal       Leicester     4     2   H
# 12  E0   8/13/22   2  15:00        Brighton       Newcastle     0     0   D
# 13  E0   8/13/22   2  15:00        Man City     Bournemouth     4     0   H
# 14  E0   8/13/22   2  15:00     Southampton           Leeds     2     2   D
# 15  E0   8/13/22   2  15:00          Wolves          Fulham     0     0   D
# 16  E0   8/13/22   2  17:30       Brentford      Man United     4     0   H
# 17  E0   8/14/22   2  14:00   Nott'm Forest        West Ham     1     0   H
# 18  E0   8/14/22   2  16:30         Chelsea       Tottenham     2     2   D
# 19  E0   8/15/22   2  20:00       Liverpool  Crystal Palace     1     1   D
# 20  E0   8/20/22   3  12:30       Tottenham          Wolves     1     0   H
# 21  E0   8/20/22   3  15:00  Crystal Palace     Aston Villa     3     1   H
# 22  E0   8/20/22   3  15:00         Everton   Nott'm Forest     1     1   D
# 23  E0   8/20/22   3  15:00          Fulham       Brentford     3     2   H
# 24  E0   8/20/22   3  15:00       Leicester     Southampton     1     2   A
# 25  E0   8/20/22   3  17:30     Bournemouth         Arsenal     0     3   A
# 26  E0   8/21/22   3  14:00           Leeds         Chelsea     3     0   H
# 27  E0   8/21/22   3  14:00        West Ham        Brighton     0     2   A
# 28  E0   8/21/22   3  16:30       Newcastle        Man City     3     3   D
# 29  E0   8/22/22   3  20:00      Man United       Liverpool     2     1   H
# 30  E0   8/27/22   4  12:30     Southampton      Man United     0     1   A
# 31  E0   8/27/22   4  15:00       Brentford         Everton     1     1   D
# 32  E0   8/27/22   4  15:00        Brighton           Leeds     1     0   H
# 33  E0   8/27/22   4  15:00         Chelsea       Leicester     2     1   H
# 34  E0   8/27/22   4  15:00       Liverpool     Bournemouth     9     0   H
# 35  E0   8/27/22   4  15:00        Man City  Crystal Palace     4     2   H
# 36  E0   8/27/22   4  17:30         Arsenal          Fulham     2     1   H
# 37  E0   8/28/22   4  14:00     Aston Villa        West Ham     0     1   A
# 38  E0   8/28/22   4  14:00          Wolves       Newcastle     1     1   D
# 39  E0   8/28/22   4  16:30   Nott'm Forest       Tottenham     0     2   A
# 40  E0   8/30/22   5  19:30  Crystal Palace       Brentford     1     1   D
# 41  E0   8/30/22   5  19:30          Fulham        Brighton     2     1   H
# 42  E0   8/30/22   5  19:45     Southampton         Chelsea     2     1   H
# 43  E0   8/30/22   5  20:00           Leeds         Everton     1     1   D
# 44  E0   8/31/22   5  19:30         Arsenal     Aston Villa     2     1   H
# 45  E0   8/31/22   5  19:30     Bournemouth          Wolves     0     0   D
# 46  E0   8/31/22   5  19:30        Man City   Nott'm Forest     6     0   H
# 47  E0   8/31/22   5  19:45        West Ham       Tottenham     1     1   D
# 48  E0   8/31/22   5  20:00       Liverpool       Newcastle     2     1   H
# 49  E0    9/1/22   5  20:00       Leicester      Man United     0     1   A
# 50  E0    9/3/22   6  12:30         Everton       Liverpool     0     0   D
# 51  E0    9/3/22   6  15:00       Brentford           Leeds     5     2   H
# 52  E0    9/3/22   6  15:00         Chelsea        West Ham     2     1   H
# 53  E0    9/3/22   6  15:00       Newcastle  Crystal Palace     0     0   D
# 54  E0    9/3/22   6  15:00   Nott'm Forest     Bournemouth     2     3   A
# 55  E0    9/3/22   6  15:00       Tottenham          Fulham     2     1   H
# 56  E0    9/3/22   6  15:00          Wolves     Southampton     1     0   H
# 57  E0    9/3/22   6  17:30     Aston Villa        Man City     1     1   D
# 58  E0    9/4/22   6  14:00        Brighton       Leicester     5     2   H
# 59  E0    9/4/22   6  16:30      Man United         Arsenal     3     1   H
# 60  E0   9/16/22   8  20:00     Aston Villa     Southampton     1     0   H
# 61  E0   9/16/22   8  20:00   Nott'm Forest          Fulham     2     3   A
# 62  E0   9/17/22   8  12:30          Wolves        Man City     0     3   A
# 63  E0   9/17/22   8  15:00       Newcastle     Bournemouth     1     1   D
# 64  E0   9/17/22   8  17:30       Tottenham       Leicester     6     2   H
# 65  E0   9/18/22   8  12:00       Brentford         Arsenal     0     3   A
# 66  E0   9/18/22   8  14:15         Everton        West Ham     1     0   H
# 67  E0   10/1/22   9  12:30         Arsenal       Tottenham     3     1   H
# 68  E0   10/1/22   9  15:00     Bournemouth       Brentford     0     0   D
# 69  E0   10/1/22   9  15:00  Crystal Palace         Chelsea     1     2   A
# 70  E0   10/1/22   9  15:00          Fulham       Newcastle     1     4   A
# 71  E0   10/1/22   9  15:00       Liverpool        Brighton     3     3   D
# 72  E0   10/1/22   9  15:00     Southampton         Everton     1     2   A
# 73  E0   10/1/22   9  17:30        West Ham          Wolves     2     0   H
# 74  E0   10/2/22   9  14:00        Man City      Man United     6     3   H
# 75  E0   10/2/22   9  16:30           Leeds     Aston Villa     0     0   D
# 76  E0   10/3/22   9  20:00       Leicester   Nott'm Forest     4     0   H
# 77  E0   10/8/22  10  15:00     Bournemouth       Leicester     2     1   H
# 78  E0   10/8/22  10  15:00         Chelsea          Wolves     3     0   H
# 79  E0   10/8/22  10  15:00        Man City     Southampton     4     0   H
# 80  E0   10/8/22  10  15:00       Newcastle       Brentford     5     1   H
# 81  E0   10/8/22  10  17:30        Brighton       Tottenham     0     1   A
# 82  E0   10/9/22  10  14:00  Crystal Palace           Leeds     2     1   H
# 83  E0   10/9/22  10  14:00        West Ham          Fulham     3     1   H
# 84  E0   10/9/22  10  16:30         Arsenal       Liverpool     3     2   H
# 85  E0   10/9/22  10  19:00         Everton      Man United     1     2   A
# 86  E0  10/10/22  10  20:00   Nott'm Forest     Aston Villa     1     1   D
#
#     HTHG  ...  AvgC<2.5  AHCh B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0      0  ...      1.76  0.50     2.09      1.84   2.04   1.88     2.09
# 1      1  ...      2.73  1.75     1.90      2.03   1.91   2.02     2.01
# 2      1  ...      1.76  0.50     1.93      2.00   1.93   2.00     1.94
# 3      1  ...      1.87 -0.25     2.08      1.85   2.10   1.84     2.14
# 4      0  ...      1.89 -1.00     1.97      1.96   1.99   1.93     2.19
# 5      2  ...      2.31 -1.50     2.07      1.86   2.04   1.88     2.08
# 6      0  ...      1.77  1.00     1.93      2.00   1.94   1.98     1.94
# 7      1  ...      1.97 -0.50     1.94      1.99   1.96   1.96     1.96
# 8      0  ...      1.94 -0.75     2.06      1.87   2.05   1.88     2.08
# 9      0  ...      2.62  1.50     1.85      2.08   1.85   2.08     2.00
# 10     1  ...      1.74 -0.75     2.05      1.85   2.07   1.87     2.07
# 11     2  ...      2.22 -1.00     1.98      1.92   1.96   1.96     1.99
# 12     0  ...      1.73 -0.25     2.11      1.79   2.13   1.82     2.14
# 13     3  ...      3.67 -2.75     1.95      1.95   1.94   1.94     1.98
# 14     0  ...      2.28 -0.25     2.09      1.81   2.12   1.83     2.13
# 15     0  ...      1.88 -0.25     1.90      2.00   1.92   2.01     1.95
# 16     4  ...      2.18  0.50     2.08      1.73   2.17   1.78     2.19
# 17     1  ...      1.96  0.50     1.90      2.00   1.93   1.99     1.96
# 18     1  ...      1.93 -0.25     1.86      2.04   1.87   2.07     1.92
# 19     0  ...      2.40 -1.75     2.06      1.84   2.08   1.83     2.08
# 20     0  ...      2.24 -1.25     2.03      1.87   2.05   1.88     2.06
# 21     1  ...      1.67 -0.25     2.08      1.73   2.17   1.78     2.19
# 22     0  ...      1.75 -0.50     1.86      2.04   1.89   2.03     1.96
# 23     2  ...      1.95  0.00     1.90      2.00   1.93   2.00     1.94
# 24     0  ...      2.37 -0.75     1.95      1.95   1.98   1.94     2.14
# 25     0  ...      2.07  1.25     1.90      2.00   1.88   2.05     1.93
# 26     2  ...      2.32  1.00     2.06      1.84   2.06   1.87     2.12
# 27     0  ...      1.86  0.00     1.83      2.07   1.86   2.08     1.86
# 28     2  ...      2.37  1.25     1.86      2.04   1.88   2.04     2.04
# 29     1  ...      2.60  0.75     2.03      1.87   2.05   1.88     2.07
# 30     0  ...      2.40  0.50     1.90      2.00   1.91   2.02     2.10
# 31     0  ...      1.82 -0.50     2.06      1.84   2.08   1.86     2.16
# 32     0  ...      1.99 -0.75     1.93      1.97   1.94   1.98     2.12
# 33     0  ...      2.32 -1.25     1.86      2.04   1.88   2.05     1.95
# 34     5  ...      3.28 -2.25     1.91      1.99   1.93   1.97     1.95
# 35     0  ...      2.66 -2.00     1.97      1.93   1.95   1.95     2.01
# 36     0  ...      2.50 -1.50     2.02      1.77   2.15   1.79     2.15
# 37     0  ...      1.89 -0.50     2.05      1.75   2.11   1.82     2.14
# 38     1  ...      1.80 -0.25     2.08      1.73   2.20   1.75     2.23
# 39     0  ...      2.30  1.25     1.87      2.03   1.88   2.06     1.95
# 40     0  ...      1.86 -0.50     2.02      1.77   2.11   1.81     2.14
# 41     0  ...      1.72  0.25     1.87      2.03   1.90   2.03     1.94
# 42     2  ...      2.09  0.75     2.05      1.85   2.05   1.88     2.11
# 43     0  ...      2.03 -0.25     1.86      2.04   1.88   2.06     1.88
# 44     1  ...      2.22 -1.00     1.90      2.00   1.91   2.02     1.98
# 45     0  ...      1.68  0.25     1.90      2.00   1.93   2.00     1.93
# 46     3  ...      4.06 -2.75     1.92      1.98   1.93   1.96     1.99
# 47     0  ...      1.99  0.25     1.93      1.97   1.94   1.98     2.00
# 48     0  ...      2.96 -1.50     1.70      2.10   1.76   2.17     1.97
# 49     0  ...      2.28  0.25     2.00      1.90   1.96   1.96     2.06
# 50     0  ...      2.56  1.50     1.80      2.00   1.83   2.11     1.87
# 51     2  ...      2.06 -0.25     1.85      2.05   1.88   2.06     1.88
# 52     0  ...      1.94 -0.75     1.88      2.02   1.88   2.05     1.91
# 53     0  ...      1.75 -0.50     2.10      1.80   2.12   1.83     2.14
# 54     2  ...      1.73 -0.25     1.87      2.03   1.89   2.04     1.94
# 55     1  ...      2.36 -1.00     1.84      2.06   1.86   2.07     1.92
# 56     1  ...      1.86 -0.25     1.89      2.01   1.84   2.10     1.89
# 57     0  ...      2.75  1.50     2.00      1.90   2.02   1.91     2.05
# 58     2  ...      1.85 -0.50     1.93      1.97   1.94   1.98     1.95
# 59     1  ...      2.13  0.00     1.92      1.98   1.97   1.95     1.97
# 60     1  ...      1.95 -0.25     1.82      2.08   1.85   2.09     1.85
# 61     1  ...      1.95  0.00     2.02      1.88   2.02   1.90     2.08
# 62     0  ...      2.41  1.50     1.95      1.95   1.98   1.94     2.07
# 63     0  ...      2.13 -1.25     1.94      1.96   1.96   1.96     1.97
# 64     2  ...      2.40 -1.00     1.88      2.02   1.91   2.02     1.92
# 65     0  ...      2.09  0.75     1.83      2.07   1.84   2.08     1.99
# 66     0  ...      1.80  0.00     2.08      1.73   2.10   1.84     2.15
# 67     1  ...      2.13 -0.50     1.97      1.93   1.99   1.89     2.03
# 68     0  ...      1.92  0.25     1.94      1.96   1.96   1.96     1.96
# 69     1  ...      1.85  0.75     1.91      1.99   1.90   2.03     1.95
# 70     0  ...      1.95  0.25     1.73      2.08   1.79   2.15     1.81
# 71     1  ...      2.39 -1.25     2.01      1.89   2.04   1.88     2.04
# 72     0  ...      1.74 -0.25     2.03      1.87   2.04   1.88     2.07
# 73     1  ...      1.69 -0.50     2.07      1.83   2.07   1.86     2.09
# 74     4  ...      2.74 -1.25     1.86      2.04   1.91   2.05     1.95
# 75     0  ...      1.96 -0.25     2.08      1.82   2.11   1.83     2.14
# 76     3  ...      2.18 -0.75     1.93      1.97   1.93   2.00     1.94
# 77     0  ...      1.94  0.25     1.99      1.91   2.01   1.92     2.01
# 78     1  ...      1.91 -1.00     1.89      2.01   1.91   2.02     1.91
# 79     2  ...      3.87 -2.50     1.97      1.93   1.96   1.94     2.00
# 80     2  ...      2.06 -0.75     1.84      2.06   1.88   2.05     1.88
# 81     0  ...      1.84  0.00     1.82      2.08   1.84   2.10     1.87
# 82     1  ...      1.93 -0.50     2.07      1.83   2.09   1.85     2.13
# 83     1  ...      1.98 -1.00     2.07      1.83   2.09   1.83     2.20
# 84     2  ...      2.51  0.00     1.91      1.99   1.93   1.99     1.96
# 85     1  ...      2.02  0.50     1.80      2.00   1.85   2.09     1.89
# 86     1  ...      1.94  0.50     1.89      2.01   1.89   2.03     1.90
#
#     MaxCAHA  AvgCAHH  AvgCAHA
# 0      1.88     2.03     1.85
# 1      2.06     1.89     1.99
# 2      2.04     1.88     2.00
# 3      1.87     2.08     1.81
# 4      1.97     2.03     1.86
# 5      1.88     2.03     1.85
# 6      2.11     1.88     2.00
# 7      2.04     1.92     1.96
# 8      1.97     2.00     1.88
# 9      2.12     1.85     2.04
# 10     1.90     2.02     1.86
# 11     2.00     1.94     1.94
# 12     1.84     2.08     1.81
# 13     2.02     1.92     1.95
# 14     1.84     2.10     1.79
# 15     2.05     1.90     1.98
# 16     1.95     2.04     1.84
# 17     2.04     1.92     1.95
# 18     2.07     1.86     2.02
# 19     2.09     2.02     1.86
# 20     1.98     2.00     1.88
# 21     1.83     2.12     1.77
# 22     2.08     1.90     1.97
# 23     2.02     1.91     1.97
# 24     1.98     1.98     1.90
# 25     2.05     1.88     1.99
# 26     1.94     2.03     1.84
# 27     2.12     1.81     2.08
# 28     2.09     1.90     1.97
# 29     1.90     2.01     1.86
# 30     2.02     1.93     1.94
# 31     1.86     2.08     1.80
# 32     2.01     1.96     1.92
# 33     2.08     1.88     2.00
# 34     2.27     1.87     2.01
# 35     1.99     1.93     1.94
# 36     2.04     2.03     1.84
# 37     1.88     2.09     1.80
# 38     1.80     2.14     1.75
# 39     2.10     1.86     2.01
# 40     1.85     2.07     1.81
# 41     2.04     1.90     1.97
# 42     1.88     2.06     1.83
# 43     2.09     1.84     2.04
# 44     2.05     1.88     1.98
# 45     2.06     1.88     1.99
# 46     2.01     1.91     1.97
# 47     2.02     1.95     1.92
# 48     2.26     1.78     2.12
# 49     1.96     1.99     1.89
# 50     2.17     1.81     2.08
# 51     2.08     1.85     2.03
# 52     2.10     1.85     2.03
# 53     1.92     2.09     1.81
# 54     2.08     1.87     2.00
# 55     2.09     1.83     2.04
# 56     2.11     1.85     2.03
# 57     1.95     1.98     1.90
# 58     2.04     1.90     1.97
# 59     2.03     1.94     1.94
# 60     2.14     1.79     2.09
# 61     1.90     2.01     1.86
# 62     2.00     1.93     1.94
# 63     2.01     1.93     1.94
# 64     2.09     1.84     2.05
# 65     2.12     1.86     2.02
# 66     1.85     2.08     1.80
# 67     1.97     1.99     1.89
# 68     2.00     1.91     1.95
# 69     2.03     1.88     1.98
# 70     2.19     1.78     2.10
# 71     1.92     2.00     1.88
# 72     1.93     1.99     1.88
# 73     1.89     2.04     1.84
# 74     2.05     1.89     1.98
# 75     1.87     2.06     1.82
# 76     2.00     1.90     1.97
# 77     1.96     1.96     1.91
# 78     2.13     1.86     2.01
# 79     2.00     1.92     1.94
# 80     2.07     1.86     2.01
# 81     2.13     1.83     2.05
# 82     1.87     2.07     1.82
# 83     1.86     2.11     1.78
# 84     2.03     1.89     1.98
# 85     2.11     1.82     2.06
# 86     2.08     1.85     2.03
#
# [87 rows x 107 columns]

# %%
matches_21 = matches_21_raw[["Date", "Time","HomeTeam", "AwayTeam", 
      "FTHG", "FTAG", "FTR", "Referee", 
      "HS", "AS", "HST", "AST", "HC", "AC", 
      "HY", "AY", "HR", "AR", "B365H", "B365D", "B365A"]]
matches_21 = matches_21.assign(HICT="")
matches_21 = matches_21.assign(AICT="")
matches_21.sort_index(inplace=True)
matches_21 = matches_21.reset_index(drop=True)

# %%
matches_22 = matches_22_raw[["Date", "GW","HomeTeam", "AwayTeam", 
      "FTHG", "FTAG", "FTR", "Referee", 
      "HS", "AS", "HST", "AST", "HC", "AC", 
      "HY", "AY", "HR", "AR", "B365H", "B365D", "B365A"]]
matches_22 = matches_22.assign(HICT="")
matches_22 = matches_22.assign(AICT="")
matches_22.sort_index(inplace=True)
matches_22 = matches_22.reset_index(drop=True)

# %%
#ICT score dataset
fantasy_21_raw[['Date', 'Time']] = fantasy_21_raw['kickoff_time'].str.split('T', 1, expand=True)
fantasy_21 = fantasy_21_raw[["team", "ict_index", "Date"]] 
fantasy_21 = fantasy_21.sort_values(by=['team', 'Date'])
fantasy_21 = fantasy_21.groupby(by=['team', 'Date'])['ict_index'].sum().to_frame()
ICT_2021 = fantasy_21.pivot_table(index=['team'], 
            columns=['Date'], values='ict_index').fillna(0)
ICT_2021.sort_index(inplace=True)
ICT_2021.reset_index(inplace=True)

# %%
#ICT score dataset
fantasy_22 = fantasy_22_raw[["team", "ict_index", "GW"]]  
fantasy_22 = fantasy_22.sort_values(by=['team', 'GW'])
fantasy_22 = fantasy_22.groupby(by=['team', 'GW'])['ict_index'].sum().to_frame()
ICT_2022 = fantasy_22.pivot_table(index=['team'], 
            columns=['GW'], values='ict_index').fillna(0)
ICT_2022.sort_index(inplace=True)
ICT_2022.reset_index(inplace=True)

# %%
#was home team dataset
fantasy_21 = fantasy_21_raw[["team", "was_home", "Date"]]
fantasy_21 = fantasy_21.sort_values(by=['team', 'Date'])
WH_2021 = fantasy_21.pivot_table(index=['team'], 
            columns=['Date'], values='was_home').fillna(0)
WH_2021.sort_index(inplace=True)
WH_2021.reset_index(inplace=True)

# %%
#was home team dataset
fantasy_22 = fantasy_22_raw[["team", "was_home", "GW"]]
fantasy_22 = fantasy_22.sort_values(by=['team', 'GW'])
WH_2022 = fantasy_22.pivot_table(index=['team'], 
            columns=['GW'], values='was_home').fillna(0)
WH_2022.sort_index(inplace=True)
WH_2022.reset_index(inplace=True)

# %%
matches_21['Date'] = pd.to_datetime(matches_21['Date'], format='%m/%d/%y')
matches_21 = matches_21.sort_values(['AwayTeam','Date']).reset_index(drop=True)
matches_21
# Out:
#           Date   Time   HomeTeam AwayTeam  FTHG  FTAG FTR     Referee  HS  AS  \
# 0   2021-08-13  20:00  Brentford  Arsenal     2     0   H    M Oliver   8  22
# 1   2021-08-28  12:30   Man City  Arsenal     5     0   H  M Atkinson  25   1
# 2   2021-09-18  15:00    Burnley  Arsenal     0     1   A    A Taylor  18  13
# 3   2021-10-02  17:30   Brighton  Arsenal     0     0   D      J Moss  21   8
# 4   2021-10-30  12:30  Leicester  Arsenal     0     2   A    M Oliver  16   9
# ..         ...    ...        ...      ...   ...   ...  ..         ...  ..  ..
# 365 2022-02-27  14:00   West Ham   Wolves     1     0   H    A Taylor  13  14
# 366 2022-03-13  14:00    Everton   Wolves     0     1   A    M Oliver   8  14
# 367 2022-04-08  20:00  Newcastle   Wolves     1     0   H    P Bankes  12   5
# 368 2022-04-24  14:00    Burnley   Wolves     1     0   H    A Taylor  14  10
# 369 2022-05-07  15:00    Chelsea   Wolves     2     2   D    P Bankes  19  14
#
#      ...  AC  HY  AY  HR  AR  B365H  B365D  B365A  HICT  AICT
# 0    ...   5   0   0   0   0   4.00   3.40   1.95
# 1    ...   0   1   2   0   1   1.25   6.00  12.00
# 2    ...   3   2   1   0   0   3.80   3.60   1.95
# 3    ...   5   2   1   0   0   3.00   3.25   2.40
# 4    ...   6   2   0   0   0   2.40   3.50   2.87
# ..   ...  ..  ..  ..  ..  ..    ...    ...    ...   ...   ...
# 365  ...   5   1   0   0   0   2.05   3.30   3.80
# 366  ...   2   2   1   1   0   2.30   3.20   3.30
# 367  ...   2   1   1   0   0   2.25   3.10   3.40
# 368  ...   6   3   1   0   0   2.70   3.00   2.87
# 369  ...   3   1   3   0   0   1.33   5.00   9.50
#
# [370 rows x 23 columns]

# %%
matches_22['Date'] = pd.to_datetime(matches_22['Date'], format='%m/%d/%y')
matches_22 = matches_22.sort_values(['AwayTeam','Date']).reset_index(drop=True)
away_team_ict_22 = ICT_2022.mask(WH_2022 == 1.0)
away_team_ict_22 = away_team_ict_22.rename({'team': 'Away Team', 1: 'GW1', 2: 'GW2', 3: 'GW3', 4: 'GW4', 
                            5: 'GW5', 6: 'GW6', 8: 'GW8', 9: 'GW9', 10: 'GW10'}, axis=1)

# %%
away_team_ict_21 = ICT_2021.mask(WH_2021 == 1.0)
away_team_rows_21 =[]
if 'Away Team' in away_team_ict_21.columns:
    away_team_ict_21 = away_team_ict_21.drop('Away Team', axis=1)  
for index, rows in away_team_ict_21.iterrows():
    my_list = [rows["2021-08-13"],rows["2021-08-14"],rows["2021-08-15"],rows["2021-08-21"],
               rows["2021-08-22"],rows["2021-08-23"],rows["2021-08-28"],rows["2021-08-29"],rows["2021-09-11"],
               rows["2021-09-12"],rows["2021-09-13"],rows["2021-09-17"],rows["2021-09-18"],rows["2021-09-19"],
               rows["2021-09-25"],rows["2021-09-26"],rows["2021-09-27"],rows["2021-10-02"],rows["2021-10-03"],
               rows["2021-10-16"],rows["2021-10-17"],rows["2021-10-18"],rows["2021-10-22"],rows["2021-10-23"],
               rows["2021-10-24"],rows["2021-10-30"],rows["2021-10-31"],rows["2021-11-01"],rows["2021-11-05"],
               rows["2021-11-06"],rows["2021-11-07"],rows["2021-11-20"],rows["2021-11-21"],rows["2021-11-27"],
               rows["2021-11-28"],rows["2021-11-30"],rows["2021-12-01"],rows["2021-12-02"],rows["2021-12-04"],
               rows["2021-12-05"],rows["2021-12-06"],rows["2021-12-10"],rows["2021-12-11"],rows["2021-12-12"],
               rows["2021-12-14"],rows["2021-12-15"],rows["2021-12-16"],rows["2021-12-18"],rows["2021-12-19"],
               rows["2021-12-26"],rows["2021-12-27"],rows["2021-12-28"],rows["2021-12-29"],rows["2021-12-30"],
               rows["2022-01-01"],rows["2022-01-02"],rows["2022-01-03"],rows["2022-01-11"],rows["2022-01-12"],
               rows["2022-01-14"],rows["2022-01-15"],rows["2022-01-16"],rows["2022-01-18"],rows["2022-01-19"],
               rows["2022-01-21"],rows["2022-01-22"],rows["2022-01-23"],rows["2022-02-05"],rows["2022-02-08"],
               rows["2022-02-09"],rows["2022-02-10"],rows["2022-02-12"],rows["2022-02-13"],rows["2022-02-15"],
               rows["2022-02-19"],rows["2022-02-20"],rows["2022-02-23"],rows["2022-02-24"],rows["2022-02-25"],
               rows["2022-02-26"],rows["2022-02-27"],rows["2022-03-01"],rows["2022-03-05"],rows["2022-03-06"],
               rows["2022-03-07"],rows["2022-03-10"],rows["2022-03-12"],rows["2022-03-13"],rows["2022-03-14"],
               rows["2022-03-16"],rows["2022-03-17"],rows["2022-03-18"],rows["2022-03-19"],rows["2022-03-20"],
               rows["2022-04-02"],rows["2022-04-03"],rows["2022-04-04"],rows["2022-04-06"],rows["2022-04-08"],
               rows["2022-04-09"],rows["2022-04-10"],rows["2022-04-16"],rows["2022-04-17"],rows["2022-04-19"],
               rows["2022-04-20"],rows["2022-04-21"],rows["2022-04-23"],rows["2022-04-24"],rows["2022-04-25"],
               rows["2022-04-28"],rows["2022-04-30"],rows["2022-05-01"],rows["2022-05-02"],rows["2022-05-07"],
               rows["2022-05-08"],rows["2022-05-10"],rows["2022-05-11"],rows["2022-05-12"],rows["2022-05-15"],
               rows["2022-05-16"],rows["2022-05-17"],rows["2022-05-19"]]
    away_team_rows_21.append(my_list)
flat_list_a21 = []
for sublist_a21 in away_team_rows_21:
    for item in sublist_a21:
        flat_list_a21.append(item)
cleanedList_a21 = [x for x in flat_list_a21 if str(x) != 'nan']
cleanedList_a21 = [x for x in cleanedList_a21 if str(x) != '0.0']
matches_21 = matches_21.assign(AICT=cleanedList_a21)

# %%
away_team_rows_22 =[]
if 'Away Team' in away_team_ict_22.columns:
    away_team_ict_22 = away_team_ict_22.drop('Away Team', axis=1)  
for index, rows in away_team_ict_22.iterrows():
    my_list =[rows.GW1, rows.GW2, rows.GW3, rows.GW4, 
              rows.GW5, rows.GW6, rows.GW8, rows.GW9, rows.GW10]
    away_team_rows_22.append(my_list)
flat_list_a22 = []
for sublist in away_team_rows_22:
    for item in sublist:
        flat_list_a22.append(item)
cleanedList_a22 = [x for x in flat_list_a22 if str(x) != 'nan']
cleanedList_a22 = [x for x in cleanedList_a22 if str(x) != '0.0']
matches_22 = matches_22.assign(AICT=cleanedList_a22)

# %%
home_team_ict_21 = ICT_2021.mask(WH_2021 == 0.0)

# %%
matches_21 = matches_21.sort_values(['HomeTeam','Date']).reset_index(drop=True)
home_team_rows_21 = []
if 'Home Team' in home_team_ict_21.columns:
    home_team_ict_21 = home_team_ict_21.drop('Home Team', axis=1)  
for index, rows in home_team_ict_21.iterrows():
    my_list = [rows["2021-08-13"],rows["2021-08-14"],rows["2021-08-15"],rows["2021-08-21"],
               rows["2021-08-22"],rows["2021-08-23"],rows["2021-08-28"],rows["2021-08-29"],rows["2021-09-11"],
               rows["2021-09-12"],rows["2021-09-13"],rows["2021-09-17"],rows["2021-09-18"],rows["2021-09-19"],
               rows["2021-09-25"],rows["2021-09-26"],rows["2021-09-27"],rows["2021-10-02"],rows["2021-10-03"],
               rows["2021-10-16"],rows["2021-10-17"],rows["2021-10-18"],rows["2021-10-22"],rows["2021-10-23"],
               rows["2021-10-24"],rows["2021-10-30"],rows["2021-10-31"],rows["2021-11-01"],rows["2021-11-05"],
               rows["2021-11-06"],rows["2021-11-07"],rows["2021-11-20"],rows["2021-11-21"],rows["2021-11-27"],
               rows["2021-11-28"],rows["2021-11-30"],rows["2021-12-01"],rows["2021-12-02"],rows["2021-12-04"],
               rows["2021-12-05"],rows["2021-12-06"],rows["2021-12-10"],rows["2021-12-11"],rows["2021-12-12"],
               rows["2021-12-14"],rows["2021-12-15"],rows["2021-12-16"],rows["2021-12-18"],rows["2021-12-19"],
               rows["2021-12-26"],rows["2021-12-27"],rows["2021-12-28"],rows["2021-12-29"],rows["2021-12-30"],
               rows["2022-01-01"],rows["2022-01-02"],rows["2022-01-03"],rows["2022-01-11"],rows["2022-01-12"],
               rows["2022-01-14"],rows["2022-01-15"],rows["2022-01-16"],rows["2022-01-18"],rows["2022-01-19"],
               rows["2022-01-21"],rows["2022-01-22"],rows["2022-01-23"],rows["2022-02-05"],rows["2022-02-08"],
               rows["2022-02-09"],rows["2022-02-10"],rows["2022-02-12"],rows["2022-02-13"],rows["2022-02-15"],
               rows["2022-02-19"],rows["2022-02-20"],rows["2022-02-23"],rows["2022-02-24"],rows["2022-02-25"],
               rows["2022-02-26"],rows["2022-02-27"],rows["2022-03-01"],rows["2022-03-05"],rows["2022-03-06"],
               rows["2022-03-07"],rows["2022-03-10"],rows["2022-03-12"],rows["2022-03-13"],rows["2022-03-14"],
               rows["2022-03-16"],rows["2022-03-17"],rows["2022-03-18"],rows["2022-03-19"],rows["2022-03-20"],
               rows["2022-04-02"],rows["2022-04-03"],rows["2022-04-04"],rows["2022-04-06"],rows["2022-04-08"],
               rows["2022-04-09"],rows["2022-04-10"],rows["2022-04-16"],rows["2022-04-17"],rows["2022-04-19"],
               rows["2022-04-20"],rows["2022-04-21"],rows["2022-04-23"],rows["2022-04-24"],rows["2022-04-25"],
               rows["2022-04-28"],rows["2022-04-30"],rows["2022-05-01"],rows["2022-05-02"],rows["2022-05-07"],
               rows["2022-05-08"],rows["2022-05-10"],rows["2022-05-11"],rows["2022-05-12"],rows["2022-05-15"],
               rows["2022-05-16"],rows["2022-05-17"],rows["2022-05-19"]]
    home_team_rows_21.append(my_list)
flat_list_h21 = []
for sublist_h21 in home_team_rows_21:
    for item in sublist_h21:
        flat_list_h21.append(item)
cleanedList_h21 = [x for x in flat_list_h21 if str(x) != 'nan']
cleanedList_h21 = [x for x in cleanedList_h21 if str(x) != '0.0']
matches_21 = matches_21.assign(HICT=cleanedList_h21)

# %%
home_team_ict_22 = ICT_2022.mask(WH_2022 == 0.0)
home_team_ict_22 = home_team_ict_22.rename({'team': 'Home Team', 1: 'GW1', 2: 'GW2', 3: 'GW3', 4: 'GW4', 
                            5: 'GW5', 6: 'GW6', 8: 'GW8', 9: 'GW9', 10: 'GW10'}, axis=1)

# %%
matches_22 = matches_22.sort_values(['HomeTeam','Date'])
home_team_rows_22 =[]
if 'Home Team' in home_team_ict_22.columns:
    home_team_ict_22.drop('Home Team', axis=1)  
for index, rows in home_team_ict_22.iterrows():
    my_list =[rows.GW1, rows.GW2, rows.GW3, rows.GW4, 
              rows.GW5, rows.GW6, rows.GW8, rows.GW9, rows.GW10]
    home_team_rows_22.append(my_list)
flat_list_h22 = []
for sublist_h22 in home_team_rows_22:
    for item in sublist_h22:
        flat_list_h22.append(item)
cleanedList_h22 = [x for x in flat_list_h22 if str(x) != 'nan']
cleanedList_h22 = [x for x in cleanedList_h22 if str(x) != '0.0']
matches_22 = matches_22.assign(HICT=cleanedList_h22)

# %%
final_dataset = matches_21.append(matches_22).reset_index(drop = 'TRUE')
final_dataset = final_dataset.sort_values(by='Date').reset_index(drop=True)
final_dataset = final_dataset.drop(['Time','GW'], axis=1)
if 'FTR' in final_dataset.columns:
    final_dataset['Result']=final_dataset['FTR']
    final_dataset = final_dataset.drop('FTR', axis=1)
final_dataset
# Out:
# /var/folders/58/8k0vd_nd0sx6lhr56sh035jm0000gn/T/ipykernel_85138/1193590147.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataset = matches_21.append(matches_22).reset_index(drop = 'TRUE')
#           Date        HomeTeam        AwayTeam  FTHG  FTAG     Referee  HS  \
# 0   2021-08-13       Brentford         Arsenal     2     0    M Oliver   8
# 1   2021-08-14         Everton     Southampton     3     1    A Madley  14
# 2   2021-08-14         Burnley        Brighton     1     2     D Coote  14
# 3   2021-08-14         Chelsea  Crystal Palace     3     0      J Moss  13
# 4   2021-08-14         Watford     Aston Villa     3     2      M Dean  13
# ..         ...             ...             ...   ...   ...         ...  ..
# 452 2022-10-09         Arsenal       Liverpool     3     2    M Oliver  11
# 453 2022-10-09  Crystal Palace           Leeds     2     1   P Tierney  13
# 454 2022-10-09        West Ham          Fulham     3     1  C Kavanagh  17
# 455 2022-10-09         Everton      Man United     1     2     D Coote  11
# 456 2022-10-10   Nott'm Forest     Aston Villa     1     1    A Taylor   6
#
#      AS  HST  AST  ...  HY  AY  HR  AR  B365H  B365D  B365A  HICT  AICT  \
# 0    22    3    4  ...   0   0   0   0   4.00   3.40   1.95  42.2  64.1
# 1     6    6    3  ...   2   0   0   0   1.90   3.50   4.00  68.1  41.2
# 2    14    3    8  ...   2   1   0   0   3.10   3.10   2.45  44.7  62.8
# 3     4    6    1  ...   0   0   0   0   1.25   5.75  13.00  55.2  26.6
# 4    11    7    2  ...   3   1   0   0   3.10   3.20   2.37  56.1  41.6
# ..   ..  ...  ...  ...  ..  ..  ..  ..    ...    ...    ...   ...   ...
# 452   8    7    3  ...   1   2   0   0   2.50   3.60   2.62  61.4  43.1
# 453  10    5    4  ...   3   3   0   0   2.05   3.50   3.60  54.2  46.2
# 454   8    8    2  ...   1   3   0   0   1.72   3.80   4.75  67.6  36.3
# 455  12    2    4  ...   2   1   0   0   3.60   3.50   2.05  40.1  54.9
# 456  12    3    2  ...   3   3   0   0   3.30   3.40   2.20  34.9  48.5
#
#      Result
# 0         H
# 1         H
# 2         A
# 3         H
# 4         H
# ..      ...
# 452       H
# 453       H
# 454       H
# 455       A
# 456       D
#
# [457 rows x 22 columns]

# %%
df10 = final_dataset[['Result', 'HICT']]
df10['Away Wins or Draws']=(df10['Result']!='D').astype(int)

my_r = df10.corr(method="spearman")
print(my_r)

def display_correlation(df):
    r = df.corr(method="spearman")
    plt.figure(figsize=(10,6))
    heatmap = sns.heatmap(df.corr(), vmin=-1, 
                      vmax=1, annot=True)
    plt.title("Spearman Correlation")
    return(r)

r_simple=display_correlation(df10)
# Out:
#                         HICT  Away Wins or Draws
# HICT                1.000000            0.044307
# Away Wins or Draws  0.044307            1.000000
# /var/folders/58/8k0vd_nd0sx6lhr56sh035jm0000gn/T/ipykernel_85138/4168150087.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df10['Away Wins or Draws']=(df10['Result']!='D').astype(int)

# %%
sns.lmplot(x='B365H',y='AICT',data=final_dataset,fit_reg=True)

# %%
pd.set_option('display.max_rows', 120)
final_dataset.dtypes
# Out:
# Date        datetime64[ns]
# HomeTeam            object
# AwayTeam            object
# FTHG                 int64
# FTAG                 int64
# Referee             object
# HS                   int64
# AS                   int64
# HST                  int64
# AST                  int64
# HC                   int64
# AC                   int64
# HY                   int64
# AY                   int64
# HR                   int64
# AR                   int64
# B365H              float64
# B365D              float64
# B365A              float64
# HICT               float64
# AICT               float64
# Result              object
# dtype: object

# %%
final_dataset.Result.describe()
# Out:
# count     457
# unique      3
# top         H
# freq      200
# Name: Result, dtype: object

# %%
final_dataset.Result.value_counts()
# Out:
# H    200
# A    146
# D    111
# Name: Result, dtype: int64

# %%
ax = final_dataset.hist(column=['Result'],bins=3, figsize=(8,6))

# %%
final_dataset.describe()
# Out:
#              FTHG        FTAG          HS          AS         HST         AST  \
# count  457.000000  457.000000  457.000000  457.000000  457.000000  457.000000
# mean     1.571116    1.273523   13.728665   11.761488    4.715536    4.096280
# std      1.412614    1.209257    5.569409    5.231274    2.635378    2.491109
# min      0.000000    0.000000    3.000000    1.000000    0.000000    0.000000
# 25%      1.000000    0.000000    9.000000    8.000000    3.000000    2.000000
# 50%      1.000000    1.000000   13.000000   11.000000    4.000000    4.000000
# 75%      2.000000    2.000000   17.000000   15.000000    6.000000    6.000000
# max      9.000000    6.000000   31.000000   31.000000   15.000000   14.000000
#
#                HC          AC          HY          AY          HR          AR  \
# count  457.000000  457.000000  457.000000  457.000000  457.000000  457.000000
# mean     5.592998    4.750547    1.706783    1.776805    0.050328    0.056893
# std      2.975889    2.805681    1.251936    1.211453    0.228661    0.231891
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      3.000000    3.000000    1.000000    1.000000    0.000000    0.000000
# 50%      5.000000    4.000000    2.000000    2.000000    0.000000    0.000000
# 75%      7.000000    6.000000    2.000000    3.000000    0.000000    0.000000
# max     15.000000   16.000000    6.000000    5.000000    2.000000    1.000000
#
#             B365H       B365D       B365A        HICT        AICT
# count  457.000000  457.000000  457.000000  457.000000  457.000000
# mean     3.033982    4.241685    4.662298   55.789934   50.657768
# std      2.315707    1.446432    4.390313   18.011599   16.683519
# min      1.060000    2.800000    1.140000   18.100000   15.600000
# 25%      1.610000    3.400000    2.150000   43.800000   38.200000
# 50%      2.250000    3.750000    3.250000   54.400000   49.400000
# 75%      3.400000    4.500000    5.500000   66.700000   60.600000
# max     19.000000   13.000000   29.000000  122.200000  110.000000
